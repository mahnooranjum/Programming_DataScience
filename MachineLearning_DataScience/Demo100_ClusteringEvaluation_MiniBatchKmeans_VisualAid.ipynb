# %% [markdown]
# # **Tame Your Python**
#
# Let's see how we can classify emails based on their contents
#
# `Leggo`

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')

# %%
def plot_dataset(X):
  plt.scatter(X[:,0], X[:,1])
  plt.show()

# %%
def evaluation_labels(y, y_pred):
  from sklearn import metrics
  adj_rand = metrics.adjusted_rand_score(y, y_pred)
  print("Adjusted Rand Score = " + str(adj_rand))

  adj_mi = metrics.adjusted_mutual_info_score(y, y_pred)
  print("Adjusted Mutual Information = " + str(adj_mi))

  h = metrics.homogeneity_score(y, y_pred)
  print("Homogeneity = " + str(h))

  v = metrics.v_measure_score(y, y_pred)
  print("V-measure = " + str(v))

  c = metrics.completeness_score(y, y_pred)
  print("Completeness = " + str(c))

  f = metrics.fowlkes_mallows_score(y, y_pred)
  print("Fowlkes-Mallows = " + str(f))

  return

def evaluation(X, y_pred):
  from sklearn import metrics  
  s = metrics.silhouette_score(X, y_pred, metric='euclidean')
  print("Silhouette Coefficient = " + str(s))

  c = metrics.calinski_harabasz_score(X, y_pred)
  print("Calinski-Harabasz  = " + str(c))

  d = metrics.davies_bouldin_score(X, y_pred)
  print("Davies-Bouldin  = " + str(d))

  return

# %%
def visual(c, X, y):
  from sklearn.cluster import MiniBatchKMeans
  cluster_object = MiniBatchKMeans(n_clusters = c)
  y_pred = cluster_object.fit_predict(X)
  colors = ['red', 'green', 'blue', 'cyan', 'black', 'yellow', 'magenta', 'brown', 'orange', 'silver', 'goldenrod', 'olive', 'dodgerblue']
  clusters = np.unique(y_pred)
  print("Cluster Labels")
  print(clusters)
  print("Evaluation")
  evaluation_labels(y, y_pred)
  evaluation(X, y_pred)
  for cluster in np.unique(y):
    row_idx = np.where(y == cluster)
    plt.scatter(X[row_idx, 0], X[row_idx, 1])
  plt.title('Dataset')
  plt.xlabel('X1')
  plt.ylabel('X2')
  plt.legend()
  plt.show()
  for cluster in clusters:
    row_idx = np.where(y_pred == cluster)
    plt.scatter(X[row_idx, 0], X[row_idx, 1])
  plt.title('Clusters')
  plt.xlabel('X1')
  plt.ylabel('X2')
  plt.legend()
  plt.show()

# %% [markdown]
# ## Get the dataset

# %%
n = 1000
from sklearn.datasets import make_moons, make_blobs, make_circles, make_s_curve
X_moons, y_moons = make_moons(n_samples = n, noise=0.1)
X_blobs, y_blobs = make_blobs(n_samples = n, n_features = 2)
X_circles, y_circles = make_circles(n_samples=n, noise=0.1, factor = 0.4)
X_scurve, y_scurve = make_s_curve(n_samples=n, noise = 0.1)
X_random = np.random.random([n, 2])
y_random = np.random.randint(0,3,size = [n])
transformation = [[0.80834549, -0.83667341], [-0.20887718, 0.85253229]]
X_aniso = np.dot(X_blobs, transformation)
y_aniso = y_blobs

# %%
plot_dataset(X_moons)

# %%
visual(2, X_moons, y_moons)
# Out:
# No handles with labels found to put in legend.
# Cluster Labels
# [0 1]
# Evaluation
# Adjusted Rand Score = 0.24725064482853065
# Adjusted Mutual Information = 0.18661297468894164
# Homogeneity = 0.18718739881915153
# V-measure = 0.1872006328492915
# Completeness = 0.18721386875083879
# Fowlkes-Mallows = 0.6232854920045131
# Silhouette Coefficient = 0.48738765677630386
# Calinski-Harabasz  = 1473.265681110404
# Davies-Bouldin  = 0.7796392009683689
# No handles with labels found to put in legend.

# %%
plot_dataset(X_blobs)

# %%
visual(3, X_blobs, y_blobs)
# Out:
# No handles with labels found to put in legend.
# Cluster Labels
# [0 1 2]
# Evaluation
# Adjusted Rand Score = 0.9293979380686901
# Adjusted Mutual Information = 0.8869091817743637
# Homogeneity = 0.8871131924899954
# V-measure = 0.887115613752934
# Completeness = 0.8871180350290896
# Fowlkes-Mallows = 0.9528850320330463
# Silhouette Coefficient = 0.5670494080397833
# Calinski-Harabasz  = 1820.368390645395
# Davies-Bouldin  = 0.6021962205196255
# No handles with labels found to put in legend.

# %%
plot_dataset(X_circles)

# %%
visual(2, X_circles, y_circles)
# Out:
# No handles with labels found to put in legend.
# Cluster Labels
# [0 1]
# Evaluation
# Adjusted Rand Score = -0.0009015788656197354
# Adjusted Mutual Information = -0.0006508188351423312
# Homogeneity = 7.215933591209696e-05
# V-measure = 7.216776977032808e-05
# Completeness = 7.217620560025914e-05
# Fowlkes-Mallows = 0.4991294064106191
# Silhouette Coefficient = 0.3250212311513767
# Calinski-Harabasz  = 523.2963665583917
# Davies-Bouldin  = 1.23132309371527
# No handles with labels found to put in legend.

# %%
plot_dataset(X_random)

# %%
visual(3, X_random, y_random)
# Out:
# No handles with labels found to put in legend.
# Cluster Labels
# [0 1 2]
# Evaluation
# Adjusted Rand Score = 0.0016214371141660792
# Adjusted Mutual Information = 0.0010787554048826901
# Homogeneity = 0.0028995226271077835
# V-measure = 0.002912317739445033
# Completeness = 0.0029252262777283654
# Fowlkes-Mallows = 0.33775287448142555
# Silhouette Coefficient = 0.3762110713485241
# Calinski-Harabasz  = 753.2902079850227
# Davies-Bouldin  = 0.8573536816176889
# No handles with labels found to put in legend.

# %%
plot_dataset(X_aniso)

# %%
visual(3, X_aniso, y_aniso)
# Out:
# No handles with labels found to put in legend.
# Cluster Labels
# [0 1 2]
# Evaluation
# Adjusted Rand Score = 0.5320033266787183
# Adjusted Mutual Information = 0.5285410986605638
# Homogeneity = 0.5290387909641376
# V-measure = 0.5294022800869104
# Completeness = 0.5297662690414019
# Fowlkes-Mallows = 0.68792346647327
# Silhouette Coefficient = 0.4582907745499875
# Calinski-Harabasz  = 2038.6867627186953
# Davies-Bouldin  = 0.7930154684870105
# No handles with labels found to put in legend.
