# %% [markdown]
# # **Tame Your Python**
#
# Let's see how we can classify emails based on their contents
#
# `Leggo`

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')

# %%
def plot_dataset(X):
  plt.scatter(X[:,0], X[:,1])
  plt.show()

# %%
def evaluation_labels(y, y_pred):
  from sklearn import metrics
  adj_rand = metrics.adjusted_rand_score(y, y_pred)
  print("Adjusted Rand Score = " + str(adj_rand))

  adj_mi = metrics.adjusted_mutual_info_score(y, y_pred)
  print("Adjusted Mutual Information = " + str(adj_mi))

  h = metrics.homogeneity_score(y, y_pred)
  print("Homogeneity = " + str(h))

  v = metrics.v_measure_score(y, y_pred)
  print("V-measure = " + str(v))

  c = metrics.completeness_score(y, y_pred)
  print("Completeness = " + str(c))

  f = metrics.fowlkes_mallows_score(y, y_pred)
  print("Fowlkes-Mallows = " + str(f))

  return

def evaluation(X, y_pred):
  from sklearn import metrics  
  s = metrics.silhouette_score(X, y_pred, metric='euclidean')
  print("Silhouette Coefficient = " + str(s))

  c = metrics.calinski_harabasz_score(X, y_pred)
  print("Calinski-Harabasz  = " + str(c))

  d = metrics.davies_bouldin_score(X, y_pred)
  print("Davies-Bouldin  = " + str(d))

  return

# %%
def visual(c, X, y):
  from sklearn.mixture import GaussianMixture
  cluster_object = GaussianMixture(n_components = c)
  y_pred = cluster_object.fit_predict(X)
  colors = ['red', 'green', 'blue', 'cyan', 'black', 'yellow', 'magenta', 'brown', 'orange', 'silver', 'goldenrod', 'olive', 'dodgerblue']
  clusters = np.unique(y_pred)
  print("Cluster Labels")
  print(clusters)
  print("Evaluation")
  evaluation_labels(y, y_pred)
  evaluation(X, y_pred)
  for cluster in clusters:
    row_idx = np.where(y == cluster)
    plt.scatter(X[row_idx, 0], X[row_idx, 1])
  plt.title('Dataset')
  plt.xlabel('X1')
  plt.ylabel('X2')
  plt.legend()
  plt.show()
  for cluster in clusters:
    row_idx = np.where(y_pred == cluster)
    plt.scatter(X[row_idx, 0], X[row_idx, 1])
  plt.title('Clusters')
  plt.xlabel('X1')
  plt.ylabel('X2')
  plt.legend()
  plt.show()

# %% [markdown]
# ## Get the dataset

# %%
n = 1000
from sklearn.datasets import make_moons, make_blobs, make_circles, make_s_curve
X_moons, y_moons = make_moons(n_samples = n, noise=0.1)
X_blobs, y_blobs = make_blobs(n_samples = n, n_features = 2)
X_circles, y_circles = make_circles(n_samples=n, noise=0.1, factor = 0.4)
X_scurve, y_scurve = make_s_curve(n_samples=n, noise = 0.1)
X_random = np.random.random([n, 2])
y_random = np.random.randint(0,3,size = [n])
transformation = [[0.80834549, -0.83667341], [-0.20887718, 0.85253229]]
X_aniso = np.dot(X_blobs, transformation)
y_aniso = y_blobs

# %%
plot_dataset(X_moons)

# %%
visual(2, X_moons, y_moons)
# Out:
# No handles with labels found to put in legend.
# Cluster Labels
# [0 1]
# Evaluation
# Adjusted Rand Score = 0.4922957896100369
# Adjusted Mutual Information = 0.3922321624472431
# Homogeneity = 0.3926706671914997
# V-measure = 0.39267123369671897
# Completeness = 0.3926718002035729
# Fowlkes-Mallows = 0.7458942968065141
# Silhouette Coefficient = 0.46494330987563387
# Calinski-Harabasz  = 1262.3097185301838
# Davies-Bouldin  = 0.8256591766211063
# No handles with labels found to put in legend.

# %%
plot_dataset(X_blobs)

# %%
visual(3, X_blobs, y_blobs)
# Out:
# No handles with labels found to put in legend.
# Cluster Labels
# [0 1 2]
# Evaluation
# Adjusted Rand Score = 0.4447454436639388
# Adjusted Mutual Information = 0.6471361540244425
# Homogeneity = 0.5791701537780046
# V-measure = 0.6478577764414085
# Completeness = 0.7350298298916947
# Fowlkes-Mallows = 0.6805623050643629
# Silhouette Coefficient = 0.5952010711771345
# Calinski-Harabasz  = 3123.23102640736
# Davies-Bouldin  = 0.9028170291218484
# No handles with labels found to put in legend.

# %%
plot_dataset(X_circles)

# %%
visual(2, X_circles, y_circles)
# Out:
# No handles with labels found to put in legend.
# Cluster Labels
# [0 1]
# Evaluation
# Adjusted Rand Score = -0.0009378756913586595
# Adjusted Mutual Information = -0.000676766413969479
# Homogeneity = 4.6169688777954205e-05
# V-measure = 4.617075455442075e-05
# Completeness = 4.6171820380092996e-05
# Fowlkes-Mallows = 0.49904612302613083
# Silhouette Coefficient = 0.3251232072313449
# Calinski-Harabasz  = 523.7632359646883
# Davies-Bouldin  = 1.2326590072975523
# No handles with labels found to put in legend.

# %%
plot_dataset(X_random)

# %%
visual(3, X_random, y_random)
# Out:
# No handles with labels found to put in legend.
# Cluster Labels
# [0 1 2]
# Evaluation
# Adjusted Rand Score = 0.0015314737748051137
# Adjusted Mutual Information = 0.0013010150747486673
# Homogeneity = 0.0031221188852719184
# V-measure = 0.003127669727476919
# Completeness = 0.0031332403426172504
# Fowlkes-Mallows = 0.33510551834677577
# Silhouette Coefficient = 0.38060505763042307
# Calinski-Harabasz  = 764.5258018939526
# Davies-Bouldin  = 0.8504948048224925
# No handles with labels found to put in legend.

# %%
plot_dataset(X_aniso)

# %%
visual(3, X_aniso, y_aniso)
# Out:
# No handles with labels found to put in legend.
# Cluster Labels
# [0 1 2]
# Evaluation
# Adjusted Rand Score = 0.5642200069957981
# Adjusted Mutual Information = 0.6223582672996821
# Homogeneity = 0.6199218618095377
# V-measure = 0.6230511267739385
# Completeness = 0.6262121440624348
# Fowlkes-Mallows = 0.7108108178284598
# Silhouette Coefficient = 0.5156123598462927
# Calinski-Harabasz  = 2382.568066946518
# Davies-Bouldin  = 0.6206401611902489
# No handles with labels found to put in legend.
